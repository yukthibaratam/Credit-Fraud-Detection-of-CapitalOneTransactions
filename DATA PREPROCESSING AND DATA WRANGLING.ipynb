# %% [markdown]
# # DATA PREPROCESSING AND DATA WRANGLING

# %%
import numpy as np
import pandas as pd

#import json

# %%
dataset= pd.read_pickle('data/pickles/df_new')
dataset.head()
# Out:
#    accountNumber  customerId  creditLimit  availableMoney  \
# 0      737265056   737265056         5000          5000.0
# 1      737265056   737265056         5000          5000.0
# 2      737265056   737265056         5000          5000.0
# 3      737265056   737265056         5000          5000.0
# 4      830329091   830329091         5000          5000.0
#
#    transactionDateTime  transactionAmount         merchantName acqCountry  \
# 0  2016-08-13T14:27:32              98.55                 Uber         US
# 1  2016-10-11T05:05:54              74.51          AMC #191138         US
# 2  2016-11-08T09:18:39               7.47           Play Store         US
# 3  2016-12-10T02:14:50               7.47           Play Store         US
# 4  2016-03-24T21:04:46              71.18  Tim Hortons #947751         US
#
#   merchantCountryCode posEntryMode  ... currentExpDate accountOpenDate  \
# 0                  US           02  ...        06/2023      2015-03-14
# 1                  US           09  ...        02/2024      2015-03-14
# 2                  US           09  ...        08/2025      2015-03-14
# 3                  US           09  ...        08/2025      2015-03-14
# 4                  US           02  ...        10/2029      2015-08-06
#
#   dateOfLastAddressChange cardLast4Digits transactionType  currentBalance  \
# 0              2015-03-14            1803        PURCHASE             0.0
# 1              2015-03-14             767        PURCHASE             0.0
# 2              2015-03-14             767        PURCHASE             0.0
# 3              2015-03-14             767        PURCHASE             0.0
# 4              2015-08-06            3143        PURCHASE             0.0
#
#   cardPresent  expirationDateKeyInMatch  isFraud  matchCVV
# 0       False                     False    False         1
# 1        True                     False    False         1
# 2       False                     False    False         1
# 3       False                     False    False         1
# 4        True                     False    False         1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Account Number , Customer Id and Card Last 4 digits

# %%
#The Two columns are similar and moreover as they are simply identifications, they will not influence Predictions
#We can drop them 

df_prep= dataset.copy()
df_prep.drop(['accountNumber','customerId','cardLast4Digits'], axis=1, inplace=True)

# %%
df_prep[df_prep.isFraud == 0]
# Out:
#         creditLimit  availableMoney  transactionDateTime  transactionAmount  \
# 0              5000         5000.00  2016-08-13T14:27:32              98.55
# 1              5000         5000.00  2016-10-11T05:05:54              74.51
# 2              5000         5000.00  2016-11-08T09:18:39               7.47
# 3              5000         5000.00  2016-12-10T02:14:50               7.47
# 4              5000         5000.00  2016-03-24T21:04:46              71.18
# ...             ...             ...                  ...                ...
# 786358        50000        48904.96  2016-12-22T18:44:12             119.92
# 786359        50000        48785.04  2016-12-25T16:20:34              18.89
# 786360        50000        48766.15  2016-12-27T15:46:24              49.43
# 786361        50000        48716.72  2016-12-29T00:30:55              49.89
# 786362        50000        48666.83  2016-12-30T20:10:29              72.18
#
#                merchantName acqCountry merchantCountryCode posEntryMode  \
# 0                      Uber         US                  US           02
# 1               AMC #191138         US                  US           09
# 2                Play Store         US                  US           09
# 3                Play Store         US                  US           09
# 4       Tim Hortons #947751         US                  US           02
# ...                     ...        ...                 ...          ...
# 786358                 Lyft         US                  US           90
# 786359             hulu.com         US                  US           09
# 786360                 Lyft         US                  US           02
# 786361          walmart.com         US                  US           09
# 786362                 Uber         US                  US           05
#
#        posConditionCode  merchantCategoryCode currentExpDate accountOpenDate  \
# 0                    01             rideshare        06/2023      2015-03-14
# 1                    01         entertainment        02/2024      2015-03-14
# 2                    01            mobileapps        08/2025      2015-03-14
# 3                    01            mobileapps        08/2025      2015-03-14
# 4                    01              fastfood        10/2029      2015-08-06
# ...                 ...                   ...            ...             ...
# 786358               01             rideshare        12/2022      2012-08-23
# 786359               01  online_subscriptions        08/2023      2012-08-23
# 786360               01             rideshare        08/2025      2012-08-23
# 786361               99         online_retail        07/2022      2012-08-23
# 786362               01             rideshare        05/2024      2012-08-23
#
#        dateOfLastAddressChange transactionType  currentBalance  cardPresent  \
# 0                   2015-03-14        PURCHASE            0.00        False
# 1                   2015-03-14        PURCHASE            0.00         True
# 2                   2015-03-14        PURCHASE            0.00        False
# 3                   2015-03-14        PURCHASE            0.00        False
# 4                   2015-08-06        PURCHASE            0.00         True
# ...                        ...             ...             ...          ...
# 786358              2012-08-23        PURCHASE         1095.04        False
# 786359              2012-08-23        PURCHASE         1214.96        False
# 786360              2012-08-23        PURCHASE         1233.85        False
# 786361              2012-08-23        PURCHASE         1283.28        False
# 786362              2012-08-23        PURCHASE         1333.17        False
#
#         expirationDateKeyInMatch  isFraud  matchCVV
# 0                          False    False         1
# 1                          False    False         1
# 2                          False    False         1
# 3                          False    False         1
# 4                          False    False         1
# ...                          ...      ...       ...
# 786358                     False    False         1
# 786359                     False    False         1
# 786360                     False    False         1
# 786361                     False    False         1
# 786362                     False    False         1
#
# [773946 rows x 19 columns]

# %% [markdown]
# ### Acquired Country and Merchant Country Code

# %%
# check bot of them how many are unique

count_acqCountry = df_prep['acqCountry'].unique()
count_acqCountry=len(count_acqCountry)
count_merchantCountryCode =len(df_prep['merchantCountryCode'].unique())

print(count_acqCountry)
print(count_merchantCountryCode)
# Out:
# 4
# 4

# %%
#The Two Fields both have similar values with only 4 uniques, I presume they will not affect our model
#Hence I will remove these fields entirely 

df_prep.drop(['acqCountry','merchantCountryCode'], axis=1, inplace=True)

# %% [markdown]
# ### Dealing with Date Time

# %% [markdown]
# The Transaction Date Time Column is very important to this Dataset. I will convert the Datatime into an epoch.
#
# This will allow us to split the Date Time into chunks
#
# There are also some relative Date Time which map the days since an event. I would like to represent them in Epoch Time as well.

# %%
#I reformat the Transaction Date Time, I format the date into the form of epoch time 
#We also create new fields that will store each of our formatted dates : Year, Month, Day etc 

def DateTimeChange(df):
    df['transDT']= pd.to_datetime(df['transactionDateTime'])
    df['transMonth']= df['transDT'].dt.month.astype(int)
    df['transDay'] = df['transDT'].dt.day.astype(int)
    df['transYear']= df['transDT'].dt.year.astype(int)
    df['transHour']= df['transDT'].dt.hour.astype(int)
    df['transactionformatted'] = df['transDT'].apply(lambda x: int(x.timestamp()))
    
    df.drop(['transactionDateTime','transDT'], axis=1, inplace=True)
    return df

# %%
#Here I repeat the above procedure for the relative dates in the dataframe that captures 'days since' type of dates.

def rel_time_change(df):
    df["dateOfLastAddressChange"] = pd.to_datetime(df["dateOfLastAddressChange"])
    df["accountOpenDate"] = pd.to_datetime(df["accountOpenDate"])
    df["currentExpDate"] = pd.to_datetime(df["currentExpDate"])
    
    df["dateOfLastAddressChangeformatted"] = df["dateOfLastAddressChange"].apply(lambda x: int(x.timestamp()))
    df["accountOpenDateformatted"] = df["accountOpenDate"].apply(lambda x: int(x.timestamp()))
    df["currentExpDateformatted"] = df["currentExpDate"].apply(lambda x: int(x.timestamp()))
    
    df["timeTillExp"] = df["currentExpDateformatted"] - df["transactionformatted"]
    df["timeSinceAccountOpening"] = df["transactionformatted"] - df["accountOpenDateformatted"]
    df["timeSinceAddressChange"] = df["transactionformatted"] - df["dateOfLastAddressChangeformatted"]
    
    df.drop(['dateOfLastAddressChange','accountOpenDate','currentExpDate','dateOfLastAddressChangeformatted','accountOpenDateformatted','currentExpDateformatted'], axis=1, inplace=True)
    
    return df

# %%
df_prep= DateTimeChange(df_prep)

# %%
df_prep = rel_time_change(df_prep)
# Out:
# C:\Users\dbavi\AppData\Local\Temp\ipykernel_11516\2972419366.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["currentExpDate"] = pd.to_datetime(df["currentExpDate"])

# %%
df_prep.columns
# Out:
# Index(['creditLimit', 'availableMoney', 'transactionAmount', 'merchantName',
#        'posEntryMode', 'posConditionCode', 'merchantCategoryCode',
#        'transactionType', 'currentBalance', 'cardPresent',
#        'expirationDateKeyInMatch', 'isFraud', 'matchCVV', 'transMonth',
#        'transDay', 'transYear', 'transHour', 'transactionformatted',
#        'timeTillExp', 'timeSinceAccountOpening', 'timeSinceAddressChange'],
#       dtype='object')

# %%
# df_prep = rel_time_change(df_prep)
df_prep.head()
# Out:
#    creditLimit  availableMoney  transactionAmount         merchantName  \
# 0         5000          5000.0              98.55                 Uber
# 1         5000          5000.0              74.51          AMC #191138
# 2         5000          5000.0               7.47           Play Store
# 3         5000          5000.0               7.47           Play Store
# 4         5000          5000.0              71.18  Tim Hortons #947751
#
#   posEntryMode posConditionCode merchantCategoryCode transactionType  \
# 0           02               01            rideshare        PURCHASE
# 1           09               01        entertainment        PURCHASE
# 2           09               01           mobileapps        PURCHASE
# 3           09               01           mobileapps        PURCHASE
# 4           02               01             fastfood        PURCHASE
#
#    currentBalance  cardPresent  ...  isFraud  matchCVV  transMonth  transDay  \
# 0             0.0        False  ...    False         1           8        13
# 1             0.0         True  ...    False         1          10        11
# 2             0.0        False  ...    False         1          11         8
# 3             0.0        False  ...    False         1          12        10
# 4             0.0         True  ...    False         1           3        24
#
#    transYear  transHour  transactionformatted  timeTillExp  \
# 0       2016         14            1471098452    214479148
# 1       2016          5            1476162354    230583246
# 2       2016          9            1478596719    275409681
# 3       2016          2            1481336090    272670310
# 4       2016         21            1458853486    426653714
#
#    timeSinceAccountOpening  timeSinceAddressChange
# 0                 44807252                44807252
# 1                 49871154                49871154
# 2                 52305519                52305519
# 3                 55044890                55044890
# 4                 20034286                20034286
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Dealing with Booleans

# %% [markdown]
# Convert all boolean features to binary 1s and 0s
#
# cardPresent, expirationDateKeyInMatch, isFraud are the Boolean features we will convert to Binary

# %%
def bool_to_binary(df):
    features=['isFraud','cardPresent','expirationDateKeyInMatch']
    df[features]= df[features].astype(int)
    return df

df_prep = bool_to_binary(df_prep)

# %%
df_prep
# Out:
#         creditLimit  availableMoney  transactionAmount         merchantName  \
# 0              5000         5000.00              98.55                 Uber
# 1              5000         5000.00              74.51          AMC #191138
# 2              5000         5000.00               7.47           Play Store
# 3              5000         5000.00               7.47           Play Store
# 4              5000         5000.00              71.18  Tim Hortons #947751
# ...             ...             ...                ...                  ...
# 786358        50000        48904.96             119.92                 Lyft
# 786359        50000        48785.04              18.89             hulu.com
# 786360        50000        48766.15              49.43                 Lyft
# 786361        50000        48716.72              49.89          walmart.com
# 786362        50000        48666.83              72.18                 Uber
#
#        posEntryMode posConditionCode  merchantCategoryCode transactionType  \
# 0                02               01             rideshare        PURCHASE
# 1                09               01         entertainment        PURCHASE
# 2                09               01            mobileapps        PURCHASE
# 3                09               01            mobileapps        PURCHASE
# 4                02               01              fastfood        PURCHASE
# ...             ...              ...                   ...             ...
# 786358           90               01             rideshare        PURCHASE
# 786359           09               01  online_subscriptions        PURCHASE
# 786360           02               01             rideshare        PURCHASE
# 786361           09               99         online_retail        PURCHASE
# 786362           05               01             rideshare        PURCHASE
#
#         currentBalance  cardPresent  ...  isFraud  matchCVV  transMonth  \
# 0                 0.00            0  ...        0         1           8
# 1                 0.00            1  ...        0         1          10
# 2                 0.00            0  ...        0         1          11
# 3                 0.00            0  ...        0         1          12
# 4                 0.00            1  ...        0         1           3
# ...                ...          ...  ...      ...       ...         ...
# 786358         1095.04            0  ...        0         1          12
# 786359         1214.96            0  ...        0         1          12
# 786360         1233.85            0  ...        0         1          12
# 786361         1283.28            0  ...        0         1          12
# 786362         1333.17            0  ...        0         1          12
#
#         transDay  transYear  transHour  transactionformatted  timeTillExp  \
# 0             13       2016         14            1471098452    214479148
# 1             11       2016          5            1476162354    230583246
# 2              8       2016          9            1478596719    275409681
# 3             10       2016          2            1481336090    272670310
# 4             24       2016         21            1458853486    426653714
# ...          ...        ...        ...                   ...          ...
# 786358        22       2016         18            1482432252    187420548
# 786359        25       2016         16            1482682834    208165166
# 786360        27       2016         15            1482853584    271152816
# 786361        29       2016          0            1482971455    173662145
# 786362        30       2016         20            1483128629    231392971
#
#         timeSinceAccountOpening  timeSinceAddressChange
# 0                      44807252                44807252
# 1                      49871154                49871154
# 2                      52305519                52305519
# 3                      55044890                55044890
# 4                      20034286                20034286
# ...                         ...                     ...
# 786358                136752252               136752252
# 786359                137002834               137002834
# 786360                137173584               137173584
# 786361                137291455               137291455
# 786362                137448629               137448629
#
# [786363 rows x 21 columns]

# %% [markdown]
# ### One Hot-Encode Categorical Variables

# %%
def encode_and_bind(df, feature_to_encode):
    for feature in feature_to_encode:
        dummies = pd.get_dummies(df[feature])
        dummies.rename(columns=lambda x: feature + '_' + str(x), inplace=True)
        df = pd.concat([df, dummies], axis=1)        
        
    return(df)

# %%
#Process the Merchant Name Column, Keep the name by deleting everything after the #, also remove trailing whitespace
df_prep["merchantName"] = df_prep["merchantName"].str.split('#').str[0].str.strip()

# define the list of categorical features to encode
feature_to_encode = ['posEntryMode', 'posConditionCode', 'merchantCategoryCode', 'transactionType', 'merchantName']

# one-hot encode the categorical features and bind the encoded features to the original DataFrame
df_prep = encode_and_bind(df_prep, feature_to_encode)

df_prep
# Out:
#         creditLimit  availableMoney  transactionAmount merchantName  \
# 0              5000         5000.00              98.55         Uber
# 1              5000         5000.00              74.51          AMC
# 2              5000         5000.00               7.47   Play Store
# 3              5000         5000.00               7.47   Play Store
# 4              5000         5000.00              71.18  Tim Hortons
# ...             ...             ...                ...          ...
# 786358        50000        48904.96             119.92         Lyft
# 786359        50000        48785.04              18.89     hulu.com
# 786360        50000        48766.15              49.43         Lyft
# 786361        50000        48716.72              49.89  walmart.com
# 786362        50000        48666.83              72.18         Uber
#
#        posEntryMode posConditionCode  merchantCategoryCode transactionType  \
# 0                02               01             rideshare        PURCHASE
# 1                09               01         entertainment        PURCHASE
# 2                09               01            mobileapps        PURCHASE
# 3                09               01            mobileapps        PURCHASE
# 4                02               01              fastfood        PURCHASE
# ...             ...              ...                   ...             ...
# 786358           90               01             rideshare        PURCHASE
# 786359           09               01  online_subscriptions        PURCHASE
# 786360           02               01             rideshare        PURCHASE
# 786361           09               99         online_retail        PURCHASE
# 786362           05               01             rideshare        PURCHASE
#
#         currentBalance  cardPresent  ...  merchantName_ikea.com  \
# 0                 0.00            0  ...                  False
# 1                 0.00            1  ...                  False
# 2                 0.00            0  ...                  False
# 3                 0.00            0  ...                  False
# 4                 0.00            1  ...                  False
# ...                ...          ...  ...                    ...
# 786358         1095.04            0  ...                  False
# 786359         1214.96            0  ...                  False
# 786360         1233.85            0  ...                  False
# 786361         1283.28            0  ...                  False
# 786362         1333.17            0  ...                  False
#
#         merchantName_netflix.com  merchantName_oldnavy.com  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 786358                     False                     False
# 786359                     False                     False
# 786360                     False                     False
# 786361                     False                     False
# 786362                     False                     False
#
#         merchantName_pottery-barn.com  merchantName_sears.com  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
# ...                               ...                     ...
# 786358                          False                   False
# 786359                          False                   False
# 786360                          False                   False
# 786361                          False                   False
# 786362                          False                   False
#
#         merchantName_staples.com  merchantName_target.com  \
# 0                          False                    False
# 1                          False                    False
# 2                          False                    False
# 3                          False                    False
# 4                          False                    False
# ...                          ...                      ...
# 786358                     False                    False
# 786359                     False                    False
# 786360                     False                    False
# 786361                     False                    False
# 786362                     False                    False
#
#         merchantName_walmart.com  merchantName_westelm.com  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 786358                     False                     False
# 786359                     False                     False
# 786360                     False                     False
# 786361                      True                     False
# 786362                     False                     False
#
#         merchantName_williamssonoma.com
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 786358                            False
# 786359                            False
# 786360                            False
# 786361                            False
# 786362                            False
#
# [786363 rows x 256 columns]

# %%
df_prep.drop(feature_to_encode, axis=1, inplace=True)

# %%
pd.to_pickle(df_prep,'data/pickles/df_prep', protocol=4)

# %% [markdown]
# ### WRANGLING

# %%
df_dup=dataset.copy()

# %%
df_dup = DateTimeChange(df_dup)

# %%
df_dup= df_dup.sort_values(['accountNumber'])
df_dup.head(5)
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 541974      100088067   100088067        50000        49424.61
# 541919      100088067   100088067        50000        50000.00
# 541920      100088067   100088067        50000        49996.04
# 541921      100088067   100088067        50000        49990.78
# 541922      100088067   100088067        50000        49758.31
#
#         transactionAmount               merchantName acqCountry  \
# 541974              10.18                   Best Pub         US
# 541919               3.96               Apple iTunes         US
# 541920               5.26  1st Sandwitch Bar #758805         US
# 541921             232.47       Blue Mountain eCards         US
# 541922              71.41            Next Day eCards         US
#
#        merchantCountryCode posEntryMode posConditionCode  ... currentBalance  \
# 541974                  US           02               01  ...         575.39
# 541919                  US           09               01  ...           0.00
# 541920                  US           02               01  ...           3.96
# 541921                  US           09               01  ...           9.22
# 541922                  US           05               01  ...         241.69
#
#        cardPresent expirationDateKeyInMatch isFraud  matchCVV transMonth  \
# 541974        True                    False   False         1         12
# 541919       False                    False   False         1          5
# 541920        True                    False   False         1          5
# 541921       False                    False   False         1          5
# 541922       False                    False   False         1          5
#
#         transDay  transYear  transHour  transactionformatted
# 541974        28       2016         12            1482928029
# 541919         5       2016         22            1462488470
# 541920         6       2016          2            1462503241
# 541921        11       2016         12            1462971326
# 541922        16       2016         20            1463430780
#
# [5 rows x 26 columns]

# %%
df_dup = df_dup.reset_index(drop=True)
df_dup.head(5)
# Out:
#    accountNumber  customerId  creditLimit  availableMoney  transactionAmount  \
# 0      100088067   100088067        50000        49424.61              10.18
# 1      100088067   100088067        50000        50000.00               3.96
# 2      100088067   100088067        50000        49996.04               5.26
# 3      100088067   100088067        50000        49990.78             232.47
# 4      100088067   100088067        50000        49758.31              71.41
#
#                 merchantName acqCountry merchantCountryCode posEntryMode  \
# 0                   Best Pub         US                  US           02
# 1               Apple iTunes         US                  US           09
# 2  1st Sandwitch Bar #758805         US                  US           02
# 3       Blue Mountain eCards         US                  US           09
# 4            Next Day eCards         US                  US           05
#
#   posConditionCode  ... currentBalance cardPresent expirationDateKeyInMatch  \
# 0               01  ...         575.39        True                    False
# 1               01  ...           0.00       False                    False
# 2               01  ...           3.96        True                    False
# 3               01  ...           9.22       False                    False
# 4               01  ...         241.69       False                    False
#
#   isFraud  matchCVV transMonth  transDay  transYear  transHour  \
# 0   False         1         12        28       2016         12
# 1   False         1          5         5       2016         22
# 2   False         1          5         6       2016          2
# 3   False         1          5        11       2016         12
# 4   False         1          5        16       2016         20
#
#    transactionformatted
# 0            1482928029
# 1            1462488470
# 2            1462503241
# 3            1462971326
# 4            1463430780
#
# [5 rows x 26 columns]

# %%
time_limit =300  # 300 seconds ie 5 minutes

# %%
df_grouped = df_dup.groupby('accountNumber')
df_grouped

# %%
reversed_trans = []
multiswipe_trans = []

# %%
for accNo, df in df_grouped:
    df = df.sort_values(['transactionAmount'])
    df = df.reset_index(drop=True)
    
    # Loop through each transaction, comparing it to every other transaction with a higher index
    for i in range(0,len(df["transactionAmount"])-1):
        for j in range(i+1,len(df["transactionAmount"])-1):
            
            # If two transactions have the same amount, calculate the time difference between them
            if df_dup ["transactionAmount"][i] == df_dup ["transactionAmount"][j]:
                
                time_difference = abs(df_dup ["transactionformatted"][j] - df_dup ["transactionformatted"][i])
            
                # If one transaction is a REVERSAL and the other is not,
                #consider the REVERSAL transaction as a potential Duplicate
                if (df_dup ["transactionType"][j] == "REVERSAL" and \
                    df_dup ["transactionType"][i] != "REVERSAL") \
                or (df_dup ["transactionType"][j] != "REVERSAL" \
                    and df_dup ["transactionType"][i] == "REVERSAL"):
                    
                    reversed_trans.append(df_dup ["transactionAmount"][j])

            
                # If the time difference between two transactions is less than or equal to a certain limit, it is a duplicate               
                elif time_difference <= time_limit:
                    
                    multiswipe_trans.append(df_dup ["transactionAmount"][j])
                    
            # The Transactions are sorted by Amount, if the amount is lesser, break out of the loop            
            elif df_dup ["transactionAmount"][i] < df_dup ["transactionAmount"][j]:
                
                break

# %%
reversed_count = len(reversed_trans)
reversed_total = round(np.array(reversed_trans).sum(),4)
multiswipe_count = len(multiswipe_trans)
multiswipe_total = round(np.array(multiswipe_trans).sum(),4)

print("There are total of {} reversed transactions amounting to ${}".format(reversed_count, reversed_total))
print("There are total of {} multiswipe transactions amounting to ${}".format(multiswipe_count, multiswipe_total))
# Out:
# There are total of 3501 reversed transactions amounting to $640960.33
# There are total of 7649 multiswipe transactions amounting to $2690437.35

# %%
df_dup['timeSinceAccountOpening']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timeSinceAccountOpening'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df_dup['timeSinceAccountOpening']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'timeSinceAccountOpening'
