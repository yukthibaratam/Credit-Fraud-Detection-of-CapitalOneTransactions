# %% [markdown]
# # LOAD THE DATA SET

# %%
import numpy as np
import pandas as pd
import requests
import zipfile
import os

# %%
dataset_url ="https://raw.github.com/CapitalOneRecruiting/DS/master/transactions.zip"

# %%
if not os.path.exists('data'):
    os.makedirs('data')
if not os.path.exists('data/pickles'):
    os.makedirs('data/pickles')

# %%
# def download_file(url: str, folder: str='data')->str:
#     filename = os.path.join("data/", url.split("/")[-1])
    
#     with requests.get(url,stream=True) as response:
#         response.raise_for_status()
#         with open(filename,"wb") as file:
#             for chunk in response.iter_content(chunk_size=8192):
#                 file.write(chunk)
#     return filename

def download_file(url: str, folder: str='data')->str:
    filename = os.path.join("data/", url.split("/")[-1])
    with requests.get(url, stream=True) as response:
        response.raise_for_status()
        with open(filename, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
    return filename

# %%
download_file("https://raw.github.com/CapitalOneRecruiting/DS/master/transactions.zip")
# Out:
# 'data/transactions.zip'

# %%
with zipfile.ZipFile("data/transactions.zip","r") as zip_ref:
    zip_ref.extractall("data/")

# %%
df = pd.read_json('data/transactions.txt', lines=True)
df.replace('', np.nan, inplace=True)
pd.to_pickle(df, 'data/pickles/df_Original', protocol=4)
df.info()

# df= pd.read_json('data/transactions.txt', lines=True)
# df.replace('',np.nan, inplace=True)
# pd.to_pickle(df,'data/pickles/df_Original',protocol=4)
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             786363 non-null  int64
#  1   customerId                786363 non-null  int64
#  2   creditLimit               786363 non-null  int64
#  3   availableMoney            786363 non-null  float64
#  4   transactionDateTime       786363 non-null  object
#  5   transactionAmount         786363 non-null  float64
#  6   merchantName              786363 non-null  object
#  7   acqCountry                781801 non-null  object
#  8   merchantCountryCode       785639 non-null  object
#  9   posEntryMode              782309 non-null  object
#  10  posConditionCode          785954 non-null  object
#  11  merchantCategoryCode      786363 non-null  object
#  12  currentExpDate            786363 non-null  object
# ...

# %%
df.head(5)
# Out:
#    accountNumber  customerId  creditLimit  availableMoney  \
# 0      737265056   737265056         5000          5000.0
# 1      737265056   737265056         5000          5000.0
# 2      737265056   737265056         5000          5000.0
# 3      737265056   737265056         5000          5000.0
# 4      830329091   830329091         5000          5000.0
#
#    transactionDateTime  transactionAmount         merchantName acqCountry  \
# 0  2016-08-13T14:27:32              98.55                 Uber         US
# 1  2016-10-11T05:05:54              74.51          AMC #191138         US
# 2  2016-11-08T09:18:39               7.47           Play Store         US
# 3  2016-12-10T02:14:50               7.47           Play Store         US
# 4  2016-03-24T21:04:46              71.18  Tim Hortons #947751         US
#
#   merchantCountryCode posEntryMode  ... echoBuffer currentBalance  \
# 0                  US           02  ...        NaN            0.0
# ...

# %%
df[df.isFraud==True]
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 694         984504651   984504651        50000         8613.80
# 971         114896048   114896048        15000        14113.96
# 1072        114896048   114896048        15000        13702.47
# 1113        114896048   114896048        15000         8943.58
# 1321        114896048   114896048        15000         5223.03
# ...               ...         ...          ...             ...
# 785680      207667444   207667444         7500         5517.88
# 785713      207667444   207667444         7500          764.48
# 785888      428856030   428856030          250           61.94
# 786054      657364505   657364505        20000        20000.00
# 786112      899818521   899818521         2500          340.38
#
#         transactionDateTime  transactionAmount              merchantName  \
# 694     2016-09-08T16:14:40             165.26         Walgreens #860120
# ...

# %%
df[df.posOnPremises!='Nan']
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 0           737265056   737265056         5000         5000.00
# 1           737265056   737265056         5000         5000.00
# 2           737265056   737265056         5000         5000.00
# 3           737265056   737265056         5000         5000.00
# 4           830329091   830329091         5000         5000.00
# ...               ...         ...          ...             ...
# 786358      732852505   732852505        50000        48904.96
# 786359      732852505   732852505        50000        48785.04
# 786360      732852505   732852505        50000        48766.15
# 786361      732852505   732852505        50000        48716.72
# 786362      732852505   732852505        50000        48666.83
#
#         transactionDateTime  transactionAmount         merchantName  \
# 0       2016-08-13T14:27:32              98.55                 Uber
# 1       2016-10-11T05:05:54              74.51          AMC #191138
# ...

# %%
df[df.posConditionCode.is_unique()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df[df.posConditionCode.is_unique()]
#
# TypeError: 'bool' object is not callable
